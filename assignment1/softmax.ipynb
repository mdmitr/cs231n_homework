# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.334212
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Generally only one class from 10 is correct, thats why loss is near to -np.log(1/10)*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 2.275744 analytic: 2.275744, relative error: 1.575336e-08
# numerical: 0.446097 analytic: 0.446097, relative error: 7.965844e-08
# numerical: 2.803798 analytic: 2.803798, relative error: 2.158968e-08
# numerical: -2.330897 analytic: -2.330897, relative error: 1.382685e-08
# numerical: -1.461388 analytic: -1.461388, relative error: 1.100137e-08
# numerical: 1.982567 analytic: 1.982567, relative error: 6.895333e-08
# numerical: -1.923046 analytic: -1.923046, relative error: 1.036191e-08
# numerical: -1.872044 analytic: -1.872044, relative error: 1.785984e-08
# numerical: -2.146341 analytic: -2.146341, relative error: 3.825729e-08
# numerical: -1.195015 analytic: -1.195015, relative error: 7.783660e-08
# numerical: -1.019507 analytic: -1.019507, relative error: 3.353005e-08
# numerical: -1.306354 analytic: -1.306354, relative error: 2.522058e-08
# numerical: 0.671834 analytic: 0.671833, relative error: 2.153429e-08
# numerical: -0.421060 analytic: -0.421060, relative error: 2.238661e-08
# numerical: 2.517266 analytic: 2.517266, relative error: 3.517117e-08
# numerical: -0.319222 analytic: -0.319222, relative error: 1.081914e-07
# numerical: 1.306591 analytic: 1.306591, relative error: 3.745442e-08
# numerical: -0.583271 analytic: -0.583272, relative error: 1.421010e-07
# numerical: -0.228685 analytic: -0.228685, relative error: 2.101662e-07
# numerical: -1.736317 analytic: -1.736317, relative error: 1.100904e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.334212e+00 computed in 0.287307s
# vectorized loss: 2.334212e+00 computed in 0.012011s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = np.linspace(1.5e-7, 3e-7, 10)
regularization_strengths = np.linspace(0.5e3, 2e4, 10)

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for lr in learning_rates:
    for reg in regularization_strengths:
        softmax = Softmax()
        print('Processing with lr = ', lr, ', reg = ', reg)
        softmax.train(X_train, y_train, lr, reg, num_iters=2500, batch_size=64, verbose=False)
        
        y_train_pred = softmax.predict(X_train)
        y_val_pred = softmax.predict(X_val)
        train_accuracy = np.mean(y_train == y_train_pred)
        val_accuracy = np.mean(y_val == y_val_pred)
        
        print(val_accuracy)
        
        results[lr, reg] = train_accuracy, val_accuracy
        
        if val_accuracy > best_val:
            best_val = val_accuracy
            best_softmax = softmax
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# Processing with lr =  1.5e-07 , reg =  500.0
# 0.301
# Processing with lr =  1.5e-07 , reg =  2666.6666666666665
# 0.374
# Processing with lr =  1.5e-07 , reg =  4833.333333333333
# 0.379
# Processing with lr =  1.5e-07 , reg =  7000.0
# 0.371
# Processing with lr =  1.5e-07 , reg =  9166.666666666666
# 0.362
# Processing with lr =  1.5e-07 , reg =  11333.333333333332
# 0.363
# Processing with lr =  1.5e-07 , reg =  13500.0
# 0.364
# Processing with lr =  1.5e-07 , reg =  15666.666666666666
# 0.353
# Processing with lr =  1.5e-07 , reg =  17833.333333333332
# 0.345
# Processing with lr =  1.5e-07 , reg =  20000.0
# 0.352
# Processing with lr =  1.6666666666666665e-07 , reg =  500.0
# 0.299
# Processing with lr =  1.6666666666666665e-07 , reg =  2666.6666666666665
# 0.388
# Processing with lr =  1.6666666666666665e-07 , reg =  4833.333333333333
# 0.39
# Processing with lr =  1.6666666666666665e-07 , reg =  7000.0
# 0.366
# Processing with lr =  1.6666666666666665e-07 , reg =  9166.666666666666
# 0.363
# Processing with lr =  1.6666666666666665e-07 , reg =  11333.333333333332
# 0.36
# Processing with lr =  1.6666666666666665e-07 , reg =  13500.0
# 0.336
# Processing with lr =  1.6666666666666665e-07 , reg =  15666.666666666666
# 0.346
# Processing with lr =  1.6666666666666665e-07 , reg =  17833.333333333332
# 0.348
# Processing with lr =  1.6666666666666665e-07 , reg =  20000.0
# 0.346
# Processing with lr =  1.8333333333333333e-07 , reg =  500.0
# 0.323
# Processing with lr =  1.8333333333333333e-07 , reg =  2666.6666666666665
# 0.387
# Processing with lr =  1.8333333333333333e-07 , reg =  4833.333333333333
# 0.385
# Processing with lr =  1.8333333333333333e-07 , reg =  7000.0
# 0.371
# Processing with lr =  1.8333333333333333e-07 , reg =  9166.666666666666
# 0.367
# Processing with lr =  1.8333333333333333e-07 , reg =  11333.333333333332
# 0.369
# Processing with lr =  1.8333333333333333e-07 , reg =  13500.0
# 0.358
# Processing with lr =  1.8333333333333333e-07 , reg =  15666.666666666666
# 0.346
# Processing with lr =  1.8333333333333333e-07 , reg =  17833.333333333332
# 0.349
# Processing with lr =  1.8333333333333333e-07 , reg =  20000.0
# 0.346
# Processing with lr =  2e-07 , reg =  500.0
# 0.298
# Processing with lr =  2e-07 , reg =  2666.6666666666665
# 0.385
# Processing with lr =  2e-07 , reg =  4833.333333333333
# 0.381
# Processing with lr =  2e-07 , reg =  7000.0
# 0.356
# Processing with lr =  2e-07 , reg =  9166.666666666666
# 0.358
# Processing with lr =  2e-07 , reg =  11333.333333333332
# 0.36
# Processing with lr =  2e-07 , reg =  13500.0
# 0.362
# Processing with lr =  2e-07 , reg =  15666.666666666666
# 0.352
# Processing with lr =  2e-07 , reg =  17833.333333333332
# 0.337
# Processing with lr =  2e-07 , reg =  20000.0
# 0.332
# Processing with lr =  2.1666666666666667e-07 , reg =  500.0
# 0.365
# Processing with lr =  2.1666666666666667e-07 , reg =  2666.6666666666665
# 0.385
# Processing with lr =  2.1666666666666667e-07 , reg =  4833.333333333333
# 0.374
# Processing with lr =  2.1666666666666667e-07 , reg =  7000.0
# 0.367
# Processing with lr =  2.1666666666666667e-07 , reg =  9166.666666666666
# 0.371
# Processing with lr =  2.1666666666666667e-07 , reg =  11333.333333333332
# 0.357
# Processing with lr =  2.1666666666666667e-07 , reg =  13500.0
# 0.353
# Processing with lr =  2.1666666666666667e-07 , reg =  15666.666666666666
# 0.348
# Processing with lr =  2.1666666666666667e-07 , reg =  17833.333333333332
# 0.347
# Processing with lr =  2.1666666666666667e-07 , reg =  20000.0
# 0.334
# Processing with lr =  2.3333333333333333e-07 , reg =  500.0
# 0.346
# Processing with lr =  2.3333333333333333e-07 , reg =  2666.6666666666665
# 0.391
# Processing with lr =  2.3333333333333333e-07 , reg =  4833.333333333333
# 0.385
# Processing with lr =  2.3333333333333333e-07 , reg =  7000.0
# 0.374
# Processing with lr =  2.3333333333333333e-07 , reg =  9166.666666666666
# 0.344
# Processing with lr =  2.3333333333333333e-07 , reg =  11333.333333333332
# 0.363
# Processing with lr =  2.3333333333333333e-07 , reg =  13500.0
# 0.357
# Processing with lr =  2.3333333333333333e-07 , reg =  15666.666666666666
# 0.356
# Processing with lr =  2.3333333333333333e-07 , reg =  17833.333333333332
# 0.351
# Processing with lr =  2.3333333333333333e-07 , reg =  20000.0
# 0.347
# Processing with lr =  2.5e-07 , reg =  500.0
# 0.341
# Processing with lr =  2.5e-07 , reg =  2666.6666666666665
# 0.383
# Processing with lr =  2.5e-07 , reg =  4833.333333333333
# 0.381
# Processing with lr =  2.5e-07 , reg =  7000.0
# 0.379
# Processing with lr =  2.5e-07 , reg =  9166.666666666666
# 0.362
# Processing with lr =  2.5e-07 , reg =  11333.333333333332
# 0.359
# Processing with lr =  2.5e-07 , reg =  13500.0
# 0.363
# Processing with lr =  2.5e-07 , reg =  15666.666666666666
# 0.358
# Processing with lr =  2.5e-07 , reg =  17833.333333333332
# 0.349
# Processing with lr =  2.5e-07 , reg =  20000.0
# 0.348
# Processing with lr =  2.6666666666666667e-07 , reg =  500.0
# 0.357
# Processing with lr =  2.6666666666666667e-07 , reg =  2666.6666666666665
# 0.375
# Processing with lr =  2.6666666666666667e-07 , reg =  4833.333333333333
# 0.372
# Processing with lr =  2.6666666666666667e-07 , reg =  7000.0
# 0.367
# Processing with lr =  2.6666666666666667e-07 , reg =  9166.666666666666
# 0.358
# Processing with lr =  2.6666666666666667e-07 , reg =  11333.333333333332
# 0.345
# Processing with lr =  2.6666666666666667e-07 , reg =  13500.0
# 0.359
# Processing with lr =  2.6666666666666667e-07 , reg =  15666.666666666666
# 0.348
# Processing with lr =  2.6666666666666667e-07 , reg =  17833.333333333332
# 0.334
# Processing with lr =  2.6666666666666667e-07 , reg =  20000.0
# 0.352
# Processing with lr =  2.833333333333333e-07 , reg =  500.0
# 0.355
# Processing with lr =  2.833333333333333e-07 , reg =  2666.6666666666665
# 0.393
# Processing with lr =  2.833333333333333e-07 , reg =  4833.333333333333
# 0.372
# Processing with lr =  2.833333333333333e-07 , reg =  7000.0
# 0.368
# Processing with lr =  2.833333333333333e-07 , reg =  9166.666666666666
# 0.35
# Processing with lr =  2.833333333333333e-07 , reg =  11333.333333333332
# 0.359
# Processing with lr =  2.833333333333333e-07 , reg =  13500.0
# 0.334
# Processing with lr =  2.833333333333333e-07 , reg =  15666.666666666666
# 0.358
# Processing with lr =  2.833333333333333e-07 , reg =  17833.333333333332
# 0.346
# Processing with lr =  2.833333333333333e-07 , reg =  20000.0
# 0.349
# Processing with lr =  3e-07 , reg =  500.0
# 0.363
# Processing with lr =  3e-07 , reg =  2666.6666666666665
# 0.404
# Processing with lr =  3e-07 , reg =  4833.333333333333
# 0.382
# Processing with lr =  3e-07 , reg =  7000.0
# 0.37
# Processing with lr =  3e-07 , reg =  9166.666666666666
# 0.375
# Processing with lr =  3e-07 , reg =  11333.333333333332
# 0.353
# Processing with lr =  3e-07 , reg =  13500.0
# 0.36
# Processing with lr =  3e-07 , reg =  15666.666666666666
# 0.358
# Processing with lr =  3e-07 , reg =  17833.333333333332
# 0.356
# Processing with lr =  3e-07 , reg =  20000.0
# 0.336
# lr 1.500000e-07 reg 5.000000e+02 train accuracy: 0.308551 val accuracy: 0.301000
# lr 1.500000e-07 reg 2.666667e+03 train accuracy: 0.374837 val accuracy: 0.374000
# lr 1.500000e-07 reg 4.833333e+03 train accuracy: 0.373857 val accuracy: 0.379000
# lr 1.500000e-07 reg 7.000000e+03 train accuracy: 0.364408 val accuracy: 0.371000
# lr 1.500000e-07 reg 9.166667e+03 train accuracy: 0.359449 val accuracy: 0.362000
# lr 1.500000e-07 reg 1.133333e+04 train accuracy: 0.356367 val accuracy: 0.363000
# lr 1.500000e-07 reg 1.350000e+04 train accuracy: 0.350694 val accuracy: 0.364000
# lr 1.500000e-07 reg 1.566667e+04 train accuracy: 0.331592 val accuracy: 0.353000
# lr 1.500000e-07 reg 1.783333e+04 train accuracy: 0.330143 val accuracy: 0.345000
# lr 1.500000e-07 reg 2.000000e+04 train accuracy: 0.335816 val accuracy: 0.352000
# lr 1.666667e-07 reg 5.000000e+02 train accuracy: 0.323204 val accuracy: 0.299000
# lr 1.666667e-07 reg 2.666667e+03 train accuracy: 0.374531 val accuracy: 0.388000
# lr 1.666667e-07 reg 4.833333e+03 train accuracy: 0.370367 val accuracy: 0.390000
# lr 1.666667e-07 reg 7.000000e+03 train accuracy: 0.360000 val accuracy: 0.366000
# lr 1.666667e-07 reg 9.166667e+03 train accuracy: 0.355571 val accuracy: 0.363000
# lr 1.666667e-07 reg 1.133333e+04 train accuracy: 0.351041 val accuracy: 0.360000
# lr 1.666667e-07 reg 1.350000e+04 train accuracy: 0.333490 val accuracy: 0.336000
# lr 1.666667e-07 reg 1.566667e+04 train accuracy: 0.339327 val accuracy: 0.346000
# lr 1.666667e-07 reg 1.783333e+04 train accuracy: 0.339510 val accuracy: 0.348000
# lr 1.666667e-07 reg 2.000000e+04 train accuracy: 0.326796 val accuracy: 0.346000
# lr 1.833333e-07 reg 5.000000e+02 train accuracy: 0.328837 val accuracy: 0.323000
# lr 1.833333e-07 reg 2.666667e+03 train accuracy: 0.382571 val accuracy: 0.387000
# lr 1.833333e-07 reg 4.833333e+03 train accuracy: 0.373286 val accuracy: 0.385000
# lr 1.833333e-07 reg 7.000000e+03 train accuracy: 0.360816 val accuracy: 0.371000
# lr 1.833333e-07 reg 9.166667e+03 train accuracy: 0.352143 val accuracy: 0.367000
# lr 1.833333e-07 reg 1.133333e+04 train accuracy: 0.353184 val accuracy: 0.369000
# lr 1.833333e-07 reg 1.350000e+04 train accuracy: 0.340653 val accuracy: 0.358000
# lr 1.833333e-07 reg 1.566667e+04 train accuracy: 0.337959 val accuracy: 0.346000
# lr 1.833333e-07 reg 1.783333e+04 train accuracy: 0.334837 val accuracy: 0.349000
# lr 1.833333e-07 reg 2.000000e+04 train accuracy: 0.336224 val accuracy: 0.346000
# lr 2.000000e-07 reg 5.000000e+02 train accuracy: 0.328612 val accuracy: 0.298000
# lr 2.000000e-07 reg 2.666667e+03 train accuracy: 0.381857 val accuracy: 0.385000
# lr 2.000000e-07 reg 4.833333e+03 train accuracy: 0.370490 val accuracy: 0.381000
# lr 2.000000e-07 reg 7.000000e+03 train accuracy: 0.362898 val accuracy: 0.356000
# lr 2.000000e-07 reg 9.166667e+03 train accuracy: 0.343755 val accuracy: 0.358000
# lr 2.000000e-07 reg 1.133333e+04 train accuracy: 0.351408 val accuracy: 0.360000
# lr 2.000000e-07 reg 1.350000e+04 train accuracy: 0.343510 val accuracy: 0.362000
# lr 2.000000e-07 reg 1.566667e+04 train accuracy: 0.340367 val accuracy: 0.352000
# lr 2.000000e-07 reg 1.783333e+04 train accuracy: 0.328633 val accuracy: 0.337000
# lr 2.000000e-07 reg 2.000000e+04 train accuracy: 0.328388 val accuracy: 0.332000
# lr 2.166667e-07 reg 5.000000e+02 train accuracy: 0.341163 val accuracy: 0.365000
# lr 2.166667e-07 reg 2.666667e+03 train accuracy: 0.383163 val accuracy: 0.385000
# lr 2.166667e-07 reg 4.833333e+03 train accuracy: 0.367388 val accuracy: 0.374000
# lr 2.166667e-07 reg 7.000000e+03 train accuracy: 0.362327 val accuracy: 0.367000
# lr 2.166667e-07 reg 9.166667e+03 train accuracy: 0.355265 val accuracy: 0.371000
# lr 2.166667e-07 reg 1.133333e+04 train accuracy: 0.351286 val accuracy: 0.357000
# lr 2.166667e-07 reg 1.350000e+04 train accuracy: 0.339102 val accuracy: 0.353000
# lr 2.166667e-07 reg 1.566667e+04 train accuracy: 0.336816 val accuracy: 0.348000
# lr 2.166667e-07 reg 1.783333e+04 train accuracy: 0.330490 val accuracy: 0.347000
# lr 2.166667e-07 reg 2.000000e+04 train accuracy: 0.330408 val accuracy: 0.334000
# lr 2.333333e-07 reg 5.000000e+02 train accuracy: 0.339224 val accuracy: 0.346000
# lr 2.333333e-07 reg 2.666667e+03 train accuracy: 0.380163 val accuracy: 0.391000
# lr 2.333333e-07 reg 4.833333e+03 train accuracy: 0.371469 val accuracy: 0.385000
# lr 2.333333e-07 reg 7.000000e+03 train accuracy: 0.362265 val accuracy: 0.374000
# lr 2.333333e-07 reg 9.166667e+03 train accuracy: 0.342878 val accuracy: 0.344000
# lr 2.333333e-07 reg 1.133333e+04 train accuracy: 0.346796 val accuracy: 0.363000
# lr 2.333333e-07 reg 1.350000e+04 train accuracy: 0.342755 val accuracy: 0.357000
# lr 2.333333e-07 reg 1.566667e+04 train accuracy: 0.341204 val accuracy: 0.356000
# lr 2.333333e-07 reg 1.783333e+04 train accuracy: 0.331959 val accuracy: 0.351000
# lr 2.333333e-07 reg 2.000000e+04 train accuracy: 0.320122 val accuracy: 0.347000
# lr 2.500000e-07 reg 5.000000e+02 train accuracy: 0.345449 val accuracy: 0.341000
# lr 2.500000e-07 reg 2.666667e+03 train accuracy: 0.382469 val accuracy: 0.383000
# lr 2.500000e-07 reg 4.833333e+03 train accuracy: 0.369286 val accuracy: 0.381000
# lr 2.500000e-07 reg 7.000000e+03 train accuracy: 0.363388 val accuracy: 0.379000
# lr 2.500000e-07 reg 9.166667e+03 train accuracy: 0.347490 val accuracy: 0.362000
# lr 2.500000e-07 reg 1.133333e+04 train accuracy: 0.345224 val accuracy: 0.359000
# lr 2.500000e-07 reg 1.350000e+04 train accuracy: 0.344429 val accuracy: 0.363000
# lr 2.500000e-07 reg 1.566667e+04 train accuracy: 0.335898 val accuracy: 0.358000
# lr 2.500000e-07 reg 1.783333e+04 train accuracy: 0.327592 val accuracy: 0.349000
# lr 2.500000e-07 reg 2.000000e+04 train accuracy: 0.331918 val accuracy: 0.348000
# lr 2.666667e-07 reg 5.000000e+02 train accuracy: 0.352490 val accuracy: 0.357000
# lr 2.666667e-07 reg 2.666667e+03 train accuracy: 0.380122 val accuracy: 0.375000
# lr 2.666667e-07 reg 4.833333e+03 train accuracy: 0.370184 val accuracy: 0.372000
# lr 2.666667e-07 reg 7.000000e+03 train accuracy: 0.349816 val accuracy: 0.367000
# lr 2.666667e-07 reg 9.166667e+03 train accuracy: 0.348122 val accuracy: 0.358000
# lr 2.666667e-07 reg 1.133333e+04 train accuracy: 0.343776 val accuracy: 0.345000
# lr 2.666667e-07 reg 1.350000e+04 train accuracy: 0.341143 val accuracy: 0.359000
# lr 2.666667e-07 reg 1.566667e+04 train accuracy: 0.338571 val accuracy: 0.348000
# lr 2.666667e-07 reg 1.783333e+04 train accuracy: 0.325939 val accuracy: 0.334000
# lr 2.666667e-07 reg 2.000000e+04 train accuracy: 0.334143 val accuracy: 0.352000
# lr 2.833333e-07 reg 5.000000e+02 train accuracy: 0.354551 val accuracy: 0.355000
# lr 2.833333e-07 reg 2.666667e+03 train accuracy: 0.382816 val accuracy: 0.393000
# lr 2.833333e-07 reg 4.833333e+03 train accuracy: 0.361163 val accuracy: 0.372000
# lr 2.833333e-07 reg 7.000000e+03 train accuracy: 0.360265 val accuracy: 0.368000
# lr 2.833333e-07 reg 9.166667e+03 train accuracy: 0.352673 val accuracy: 0.350000
# lr 2.833333e-07 reg 1.133333e+04 train accuracy: 0.356857 val accuracy: 0.359000
# lr 2.833333e-07 reg 1.350000e+04 train accuracy: 0.334755 val accuracy: 0.334000
# lr 2.833333e-07 reg 1.566667e+04 train accuracy: 0.337449 val accuracy: 0.358000
# lr 2.833333e-07 reg 1.783333e+04 train accuracy: 0.331143 val accuracy: 0.346000
# lr 2.833333e-07 reg 2.000000e+04 train accuracy: 0.337531 val accuracy: 0.349000
# lr 3.000000e-07 reg 5.000000e+02 train accuracy: 0.363041 val accuracy: 0.363000
# lr 3.000000e-07 reg 2.666667e+03 train accuracy: 0.383694 val accuracy: 0.404000
# lr 3.000000e-07 reg 4.833333e+03 train accuracy: 0.367122 val accuracy: 0.382000
# lr 3.000000e-07 reg 7.000000e+03 train accuracy: 0.362143 val accuracy: 0.370000
# lr 3.000000e-07 reg 9.166667e+03 train accuracy: 0.352776 val accuracy: 0.375000
# lr 3.000000e-07 reg 1.133333e+04 train accuracy: 0.340082 val accuracy: 0.353000
# lr 3.000000e-07 reg 1.350000e+04 train accuracy: 0.344898 val accuracy: 0.360000
# lr 3.000000e-07 reg 1.566667e+04 train accuracy: 0.339449 val accuracy: 0.358000
# lr 3.000000e-07 reg 1.783333e+04 train accuracy: 0.346592 val accuracy: 0.356000
# lr 3.000000e-07 reg 2.000000e+04 train accuracy: 0.321490 val accuracy: 0.336000
# best validation accuracy achieved during cross-validation: 0.404000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.387000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
